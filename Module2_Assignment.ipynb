# %%
import pandas as pd
import requests
import networkx as nx

# %%
l = requests.get("https://restcountries.com/v3.1/all?fields=name")
j = requests.get("https://restcountries.com/v3.1/all?fields=currencies")
k = requests.get("https://restcountries.com/v3.1/all?fields=languages")

# %%
df = pd.DataFrame(columns=['name','currencies','languages','num_currencies','num_languages','curr-Lang Ratio'])

# %%
for x in range(len(l.json())):
    cur = len(list(j.json()[x]['currencies'].keys()))
    lan = len(list(k.json()[x]['languages'].keys()))
    if cur ==  0:
        cur = 1
    if lan ==0:
        lan = 1
    df.loc[len(df.index)] = [l.json()[x]['name']['common'],list(j.json()[x]['currencies'].keys()),list(k.json()[x]['languages'].keys()),len(list(j.json()[x]['currencies'].keys())),len(list(k.json()[x]['languages'].keys())),cur/lan]

# %%
df.sort_values(by=['curr-Lang Ratio'],ascending=False)
# Out:
#              name       currencies  \
# 39      Palestine  [EGP, ILS, JOD]
# 207      Cambodia       [KHR, USD]
# 176          Cuba       [CUC, CUP]
# 138        Bhutan       [BTN, INR]
# 47        Bahamas       [BSD, USD]
# ..            ...              ...
# 129   Switzerland            [CHF]
# 25        Namibia       [NAD, ZAR]
# 57       DR Congo            [CDF]
# 40   South Africa            [ZAR]
# 225      Zimbabwe            [ZWL]
#
#                                              languages  num_currencies  \
# 39                                               [ara]               3
# 207                                              [khm]               2
# 176                                              [spa]               2
# 138                                              [dzo]               2
# 47                                               [eng]               2
# ..                                                 ...             ...
# ...

# %%
# Out:
# name                     Palestine
# currencies         [EGP, ILS, JOD]
# languages                    [ara]
# num_currencies                   3
# num_languages                    1
# curr-Lang Ratio                3.0
# Name: 39, dtype: object

# %%
for initrow in df.iterrows():
    add = initrow[1]['name']
    g.add_node(add)

# %%
for initrow in df.iterrows():
    print(initrow[1]['languages'])
# Out:
# ['spa']
# ['prs', 'pus', 'tuk']
# ['ara', 'eng']
# ['bul']
# ['deu']
# ['lit']
# ['fra']
# ['eng', 'mah']
# ['pol']
# ['eng', 'smo', 'tkl']
# ['eng', 'swa']
# ['por', 'zho']
# ['por', 'tet']
# ['fra']
# ['ces', 'slk']
# ['fra']
# ['eng', 'swa']
# ['eng']
# ['ara']
# ['ukr']
# ['est']
# ['ell']
# ['ara']
# ['kat']
# ['eng', 'fra', 'nld']
# ['afr', 'deu', 'eng', 'her', 'hgm', 'kwn', 'loz', 'ndo', 'tsn']
# ['mkd']
# ['eng', 'fra', 'mfe']
# ['eng', 'gil']
# ['fra', 'kon', 'lin']
# ['fra', 'por', 'spa']
# ['eng']
# ['eng', 'niu']
# ['sqi', 'srp']
# ['eng', 'pau']
# ['ara']
# ['eng']
# ['eng']
# ['eng', 'tsn']
# ['ara']
# ['afr', 'eng', 'nbl', 'nso', 'sot', 'ssw', 'tsn', 'tso', 'ven', 'xho', 'zul']
# ['vie']
# ['eng', 'fra', 'nrf']
# ['eng']
# ['eng', 'tvl']
# ['ara']
# ['eng', 'hmo', 'tpi']
# ['eng']
# ['por']
# ['ara']
# ['spa']
# ['aym', 'grn', 'que', 'spa']
# ['ara']
# ['eng', 'fra']
# ['nno', 'nob', 'smi']
# ['kir', 'rus']
# ['hye']
# ['fra', 'kon', 'lin', 'lua', 'swa']
# ...

# %%
for initrow in df.iterrows():
    for row in df.iterrows():
        left = initrow[1]['name']
        right = row[1]['name']
        if left != right:
            for initlang in initrow[1]['languages']:
                for lang in row[1]['languages']:
                    if initlang == lang:
                        if g.has_edge(left,right):
                            g[left][right]['weight'] +=1
                        else:
                            g.add_edge(left,right, weight = 1)
# Out:
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# hasnt
# ...

# %%
# Out:
# EdgeDataView([])

# %%
fd = pd.DataFrame(g.degree(), columns = ['name', 'degree'])

# %%
fd.sort_values(by=['degree'],ascending=False)
# Out:
#              name  degree
# 24   Sint Maarten     130
# 216       Vanuatu     127
# 157        Rwanda     127
# 191    Seychelles     127
# 53         Canada     127
# ..            ...     ...
# 138        Bhutan       0
# 198         Japan       0
# 197       Iceland       0
# 56        Armenia       0
# 98     Montenegro       0
#
# [250 rows x 2 columns]

# %%
sint_maarten = nx.ego_graph(g,"Sint Maarten", radius=3, center=True)
nx.write_graphml(sint_maarten, "sint.graphml")

# %%
Vanuatu = nx.ego_graph(g,"Vanuatu", radius=3, center=True)
nx.write_graphml(Vanuatu, "Vanuatu.graphml")

# %%
Rwanda = nx.ego_graph(g,"Rwanda", radius=3, center=True)
nx.write_graphml(Vanuatu, "Rwanda.graphml")
